# %% [markdown]
# # Generating microstructures using Dream3D
# #### Setup instructions
# Download Dream3D from Bluequartz. Unzip the folder and place it in Dream3D-build folder in Research (base) directory
#
# ```Research/Dream3D-build/```
#
# Then set location of Dream3D pipeline executable according to Dream3D version (replace **DREAM3D-6.5.171-Win64** in cell below with version)

# %%
# Location of DREAM.3D 'PipelineRunner.exe' file; this should be in the DREAM.3D program folder
d3d_pipeline_relative_path = '\\Dream3D-build\\DREAM3D-6.5.171-Win64\\PipelineRunner.exe"'

# %% [markdown]
# Then import gen_microstructures function from src package

# %%
import os
import sys
from pathlib import Path
import numpy as np

# Adds generate_microstructures src to path
sys.path.insert(0, '../src')

from generate_microstructures import gen_microstructures, print_params

# %%
# Get name of directory that contains the PRISMS-Fatigue scripts
DIR_LOC = os.path.join(os.path.dirname(os.getcwd()), "src") 
DIR_LOC
# Out:
# 'E:\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\src'

# %% [markdown]
# Next set up parameters for microstructure generating:

# %%
# Number of microstructure instantiations to generate using DREAM.3D
num_instantiations = 100

# %%
''' Specify directories and paths '''
# Directory where microstructure data should be generated and pre-processed
# This command creates a directory in the same location as the "PRISMS-Fatigue" directory with python scripts and DREAM.3D files
directory = os.path.dirname(DIR_LOC) + '\\generated_microstructures\\'

# Alternatively, the directory can be expressed as an absolute path as:
# directory = r'C:\Users\stopk\Documents\GitHub\PRISMS-Fatigue\tutorial\test_run_1'

# Location of DREAM.3D input file; should consist of only the "StatsGenerator" and "Write DREAM.3D Data File"
# "StatsGenerator" inputs include grain size distribution, crystallographic texture, grain morphology, etc.
# Six ".dream3d" files are included in PRISMS-Fatigue
d3d_input_file = os.path.abspath(DIR_LOC) + '\\Al7075_random_texture_equiaxed_grains.dream3d'

# Once again, this may be specified using an absolute path as:
# d3d_input_file = r'C:\Users\stopk\Documents\GitHub\PRISMS-Fatigue\Al7075_cubic_texture_equiaxed_grains.dream3d'

# Location of DREAM.3D 'PipelineRunner.exe' file;
d3d_executable_path = '"' + os.path.abspath(Path(DIR_LOC).parents[0]) + d3d_pipeline_relative_path

# Average grain size as determined in the "StatsGenerator" filter of the .dream3d file above
# Used for automated band and sub-band sizing as shown below but which can be overwritten by the user
# Therefore, this does NOT change the grain size generated and only affects the way in which microstructures are banded and sub-banded!
avg_grain_size = 0.014 # millimeters

# Location of DREAM.3D .json pipeline
# This can be modified by the user to include additional outputs
d3d_pipeline_path = os.path.abspath(DIR_LOC) + '\\Dream3D_microstructure_pipeline.json'

# Once again, this may be specified using an absolute path as:
# d3d_pipeline_path = r'C:\Users\stopk\Documents\GitHub\PRISMS-Fatigue\Dream3D_microstructure_pipeline.json'

''' Specify desired microstructure size and shape '''
# Size of microstructure instantiations in millimeters, in the X, Y, and Z directions, respectively.
size  = np.asarray([.0725,.0725,.0725])

# Shape of microstructure instantiations (number of voxels/elements), in the X, Y, and Z directions, respectively.
# IMPORTANT: at this point, only CUBIC voxel functionality supported even with a non-cubic microstructure
# I.e., size = [.05, .1, .025] and shape = [50, 100, 25] is acceptable
shape = np.asarray([29,29,29])

''' Specify details of banding and sub-banding process '''
# Specify the number of elements in each sub-band for volume averaging
# Please see the references below for more information
# WARNING!: If this is too low for very refined grains, this module will take a long time to run!
# This is because it attempts to determine all UNIQUE combinations of some number of neighboring elements

# NOTE: Aim for ~8-10% of the average grain volume as the num_vox, as specified below
# This is especially important when comparing microstructures with different grain sizes!
num_vox_percentage = 0.10

# This line calculates num_vox to be "num_vox_percentage" percent of the predicted average number of elements per grain
num_vox = np.around(np.prod(shape) / (np.prod(size) / ( (1.0/6.0) * np.pi * avg_grain_size ** 3  ) ) * num_vox_percentage).astype(int)

# Comment out the above line and uncomment the line below to manually set the number of elements per sub-band
# num_vox = 8

# Specify the thickness of bands in terms of number of elements
# Ideally, this should result in approximately 6 bands for coarser grains (~100 elements per grain)
# NOTE: This should also be ~one or a few micrometers in thickness based on experimental observations of slip bands
# See reference below, Castelluccio and McDowell

# This line calculates the band thickness IN MULTIPLES OF element thickness
band_thickness = np.around( avg_grain_size / ( 6 * size[0]/shape[0]) )
if band_thickness < 1:
    # The microstructure is relatively coarse so need to override band thickness to 1 element in width
    print('Setting band thickness to 1 element in width')
    band_thickness = 1.0

# Comment out the above line and uncomment the line below to manually set the band element thickness
# Set as float for subsequent calculations
# band_thickness = 3.0

# Number of crystallographic slip planes for FIP Volume averaging
# There are four slip planes in the Al 7075-T6 material system (see references below)
num_planes = 4

# Specify whether bands in grains should be further assigned to unique sub-bands
# WARNING!: this is slow for a) microstructures with many grains, and 2) very fine grains, i.e., thousands of elements per grain
# NOTE: Microstructure(s) can be created with this intially set to False, and the "gen_microstructures" can be executed with the variable "generate_new_microstructure_files" set to False, so that the SAME microstructure(s) can undergo the sub-banding process at a later time.
create_sub_bands = True

# Specify whether the centroids of grains split by the microstructure boundary should be manipulated to reflect periodicity
# Setting this to False will substantially increase the speed at which microstructures are pre-processed, but will reduce the accuracy of computed and volume-averaged fatigue indicator parameters downstream!
# Users can set this to False but rerun this script with "generate_new_microstructure_files" set to False and "compute_kosher_grain_centroids" set to True to compute the realistic grain centroids at a later time
compute_kosher_grain_centroids = True

''' Specify boundary conditions '''
# Boundary conditions, either "periodic" or "free surface", for X,Y,Z directions
# Three possible combinations: 1) all 'periodic', 2) all 'free', or 3) two 'periodic' + one 'free'
face_bc = ['periodic', 'periodic', 'periodic']

# Specify whether DREAM.3D was previously executed on these files
# If set to False, the script will NOT generate new DREAM.3D microstructure(s) and instead process the existing microstructures by reading the .csv and GrainID_#.txt files
# Reasons to set this to False:
#     1) Process the same set of microstructures with a different number of elements per sub-band, and store these in a separate folder. In this case, copy over the .csv and GrainID_#.txt files to a new folder and run this script.
#     2) Generate a set of ['periodic', 'periodic', 'periodic'] microstructures, and then reprocesses them with one set of faces set to non-periodic, i.e., ['periodic', 'free', 'periodic'], to study bulk vs. surface fatigue effects.
# NOTE: If the variable is set to False, all that is needed in the folder is the DREAM.3D exported .csv and "grainID.txt" files for each microstructure
generate_new_microstructure_files = True

# Print the parameters of this microstructure set to a text file
print_params(directory, size, shape, face_bc, num_vox, band_thickness, num_planes, num_instantiations, d3d_input_file)
directory, size, shape, face_bc, num_vox, band_thickness, num_planes, num_instantiations, d3d_input_file
# Out:
# ('E:\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\generated_microstructures\\',
#  array([0.0725, 0.0725, 0.0725]),
#  array([29, 29, 29]),
#  ['periodic', 'periodic', 'periodic'],
#  9,
#  1.0,
#  4,
#  100,
#  'E:\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\src\\Al7075_random_texture_equiaxed_grains.dream3d')

# %%
# Call to the main function
gen_microstructures(directory, size, shape, face_bc, num_vox, band_thickness, num_planes, create_sub_bands, num_instantiations, generate_new_microstructure_files, compute_kosher_grain_centroids, d3d_input_file, d3d_pipeline_path, d3d_executable_path)
# Out:
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_0.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_1.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_2.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_3.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_4.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_5.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_6.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_7.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_8.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_9.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_10.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_11.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_12.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_13.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_14.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_15.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_16.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_17.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_18.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_19.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_20.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_21.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_22.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_23.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_24.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_25.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_26.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_27.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_28.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_29.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_30.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_31.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_32.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_33.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_34.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_35.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_36.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_37.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_38.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_39.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_40.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_41.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_42.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_43.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_44.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_45.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_46.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_47.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_48.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_49.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_50.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_51.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_52.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_53.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_54.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_55.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_56.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_57.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_58.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_59.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_60.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_61.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_62.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_63.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_64.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_65.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_66.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_67.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_68.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_69.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_70.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_71.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_72.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_73.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_74.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_75.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_76.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_77.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_78.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_79.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_80.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_81.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_82.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_83.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_84.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_85.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_86.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_87.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_88.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_89.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_90.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_91.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_92.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_93.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_94.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_95.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_96.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_97.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_98.vtk
# Current output microstructure file: E:/OneDrive/UWM/William_Musinski__Surana/Research_Code/Research/generated_microstructures//Output_FakeMatl_99.vtk
# Band width of 0.0025
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.0% grains
# Finished 71.9% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5294
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.49 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.2% grains
# Finished 70.4% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5464
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.14 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.5% grains
# Finished 70.9% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5396
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.23 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 32.5% grains
# Finished 64.9% grains
# Finished 97.4% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5446
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.21 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5318
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.43 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 32.9% grains
# Finished 65.8% grains
# Finished 98.7% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5389
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.28 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.78 seconds
# Amount of bands in total is 5237
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.42 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.5% grains
# Finished 70.9% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5370
# Time to band microstructure: 0.23 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.12 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 38.5% grains
# Finished 76.9% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5364
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.15 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5381
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.33 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.2% grains
# Finished 70.4% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5353
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.21 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.69 seconds
# Amount of bands in total is 5259
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.45 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.2% grains
# Finished 70.4% grains
# Time to determine kosher element centroids: 0.78 seconds
# Amount of bands in total is 5411
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.18 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.8% grains
# Finished 73.5% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5342
# Time to band microstructure: 0.17 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.28 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5260
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.20 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 33.1% grains
# Finished 66.2% grains
# Finished 99.3% grains
# Time to determine kosher element centroids: 0.78 seconds
# Amount of bands in total is 5360
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.38 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.9% grains
# Finished 75.8% grains
# Time to determine kosher element centroids: 0.69 seconds
# Amount of bands in total is 5331
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.26 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5401
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.25 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5360
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.27 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.8% grains
# Finished 73.5% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5253
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.45 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5418
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.20 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.0% grains
# Finished 68.0% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5374
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.30 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.5% grains
# Finished 69.0% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5372
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.25 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 38.2% grains
# Finished 76.3% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5415
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.06 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.66 seconds
# Amount of bands in total is 5308
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.12 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.69 seconds
# Amount of bands in total is 5303
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.22 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.2% grains
# Finished 72.5% grains
# Time to determine kosher element centroids: 0.68 seconds
# Amount of bands in total is 5267
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.38 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.2% grains
# Finished 70.4% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5401
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.32 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.2% grains
# Finished 72.5% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5406
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.10 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5326
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.26 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.2% grains
# Finished 72.5% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5257
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.38 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.5% grains
# Finished 70.9% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5377
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.15 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.5% grains
# Finished 70.9% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5392
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.14 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.79 seconds
# Amount of bands in total is 5277
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.41 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.0% grains
# Finished 68.0% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5356
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.24 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.2% grains
# Finished 70.4% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5320
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.39 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5474
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.10 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5228
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.54 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.5% grains
# Finished 69.0% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5329
# Time to band microstructure: 0.21 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.34 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.0% grains
# Finished 71.9% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5303
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.37 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5452
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.08 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5398
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.23 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.5% grains
# Finished 69.0% grains
# Time to determine kosher element centroids: 0.79 seconds
# Amount of bands in total is 5450
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.16 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 38.8% grains
# Finished 77.5% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5343
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.18 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.8% grains
# Finished 73.5% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5296
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.45 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 33.8% grains
# Finished 67.6% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5400
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.16 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5353
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.30 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.3% grains
# Finished 74.6% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5394
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.14 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.0% grains
# Finished 74.1% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5241
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.30 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.0% grains
# Finished 68.0% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5332
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.16 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5353
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.40 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5374
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.22 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.3% grains
# Finished 74.6% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5384
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.24 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.5% grains
# Finished 70.9% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5342
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.08 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.0% grains
# Finished 71.9% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5388
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.05 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5354
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.18 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5333
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.01 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5283
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.34 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.9% grains
# Finished 75.8% grains
# Time to determine kosher element centroids: 0.69 seconds
# Amount of bands in total is 5346
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.16 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.3% grains
# Finished 74.6% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5295
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.37 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.2% grains
# Finished 68.5% grains
# Time to determine kosher element centroids: 0.81 seconds
# Amount of bands in total is 5406
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.22 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.79 seconds
# Amount of bands in total is 5388
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.18 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.3% grains
# Finished 74.6% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5365
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.27 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5249
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.37 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5167
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.65 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.2% grains
# Finished 72.5% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5334
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.26 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5414
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.22 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.8% grains
# Finished 73.5% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5394
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.13 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.2% grains
# Finished 70.4% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5373
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.36 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.0% grains
# Finished 71.9% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5405
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.09 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5341
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.33 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5250
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.63 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 38.5% grains
# Finished 76.9% grains
# Time to determine kosher element centroids: 0.70 seconds
# Amount of bands in total is 5293
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.35 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5498
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.09 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.74 seconds
# Amount of bands in total is 5383
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.25 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 39.1% grains
# Finished 78.1% grains
# Time to determine kosher element centroids: 0.78 seconds
# Amount of bands in total is 5284
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.48 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.7% grains
# Finished 69.4% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5331
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.38 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5362
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.18 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.5% grains
# Finished 69.0% grains
# Time to determine kosher element centroids: 0.71 seconds
# Amount of bands in total is 5282
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.35 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5374
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.20 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.0% grains
# Finished 69.9% grains
# Time to determine kosher element centroids: 0.79 seconds
# Amount of bands in total is 5355
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.34 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.5% grains
# Finished 69.0% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5451
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.28 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.2% grains
# Finished 68.5% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5342
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.28 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.3% grains
# Finished 74.6% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5361
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.25 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 39.1% grains
# Finished 78.1% grains
# Time to determine kosher element centroids: 0.69 seconds
# Amount of bands in total is 5255
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.38 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.0% grains
# Finished 74.1% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5417
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.25 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5256
# Time to band microstructure: 0.21 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.48 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.0% grains
# Finished 74.1% grains
# Time to determine kosher element centroids: 0.77 seconds
# Amount of bands in total is 5430
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.19 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.5% grains
# Finished 69.0% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5392
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.17 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.83 seconds
# Amount of bands in total is 5256
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.52 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 37.6% grains
# Finished 75.2% grains
# Time to determine kosher element centroids: 0.70 seconds
# Amount of bands in total is 5304
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.45 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.2% grains
# Finished 68.5% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5415
# Time to band microstructure: 0.23 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 4.97 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 34.2% grains
# Finished 68.5% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5354
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.14 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.5% grains
# Finished 70.9% grains
# Time to determine kosher element centroids: 0.80 seconds
# Amount of bands in total is 5313
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.27 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.2% grains
# Finished 72.5% grains
# Time to determine kosher element centroids: 0.73 seconds
# Amount of bands in total is 5373
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.20 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.76 seconds
# Amount of bands in total is 5383
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.19 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.5% grains
# Finished 73.0% grains
# Time to determine kosher element centroids: 0.83 seconds
# Amount of bands in total is 5394
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.34 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 39.7% grains
# Finished 79.4% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5266
# Time to band microstructure: 0.19 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.32 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 35.7% grains
# Finished 71.4% grains
# Time to determine kosher element centroids: 0.72 seconds
# Amount of bands in total is 5276
# Time to band microstructure: 0.20 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.39 seconds
# Calculate realistic grain centroids
#
# Finished 0.0% grains
# Finished 36.2% grains
# Finished 72.5% grains
# Time to determine kosher element centroids: 0.75 seconds
# Amount of bands in total is 5380
# Time to band microstructure: 0.18 seconds
# Sub-banding grain: 0
# Sub-banding grain: 100
# Sub-banding grain: 200
# Sub-banding complete
# Sub-band generation time: 5.23 seconds
# Total time to generate microstructures: 1625.44 seconds
