# %% [markdown]
# # 4. Hyperparameter Tuning for GNNs using Ray Tune
#   This notebook performs hyperparameter tuning for GNNs using Ray Tune. It defines a GNN model, a training function, and a search space for hyperparameters. It utilizes Ray Tune to search for the best hyperparameters based on a given metric. The results are stored in the storage path defined in the notebook and can be visualized using TensorBoard.
# ### 4.1 Setup instructions
# Before starting the hyperparameter tuning process, ensure that the dataset exists at the specified path mentioned in the notebook.

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

import os
import ray
from ray import tune
from ray.tune.tune_config import TuneConfig
from ray.air.config import RunConfig
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

from ray.air import session
from ray.air.checkpoint import Checkpoint

# %% [markdown]
# Let's start by defining the dataset location and the storage path for Ray Tune results. If the storage path already exists, the experiment name will be incremented by 1 (e.g. tune_analyzing_results_1). The experiment name and storage path will be printed out. We are trying to keep the experiment name unique so that we can easily find the results in the storage path and visualize them using TensorBoard.

# %%
# Define the storage path for Ray Tune results
storage_path = "./ray_results"
exp_name = "tune_analyzing_results"
dataset_path = "datasets/data.pt"

# if experiment path exists, increment number on experiment name (e.g. tune_analyzing_results_1)
i = 0
new_exp_name = f"{exp_name}_{i}"
while os.path.exists(f"{storage_path}/{new_exp_name}"):
    i += 1
    new_exp_name = f"{exp_name}_{i}"

exp_name = new_exp_name
experiment_path = f"{storage_path}/{exp_name}"

print("CUDA:", torch.cuda.is_available())
print("Experiment name:", exp_name)
print("Storage path:", storage_path)
# Out:
# CUDA: True
# Experiment name: tune_analyzing_results_2
# Storage path: ./ray_results

# %% [markdown]
# ### 4.2 Define the GCN model
# See section 5.2 for more details on the GCN model. Should be imported from there, but can't due to bug with raytune and importing from another notebook.
# To see bug, use the following code instead of the GCN class defined below:
# ```python
# import import_ipynb
# from _5_Surface_Feature_GNN import GCN
# ```

# %%
class GCN(torch.nn.Module):
    def __init__(self, num_features, num_classes, num_neurons, network_size):
        super(GCN, self).__init__()

        self.conv_layers = torch.nn.ModuleList()
        self.conv_layers.append(GCNConv(num_features, num_neurons))
        for _ in range(network_size - 1):
            self.conv_layers.append(GCNConv(num_neurons, num_neurons))
        self.conv_layers.append(GCNConv(num_neurons, num_classes))

    def forward(self, data):
        x, edge_index, edge_weight = data.x, data.edge_index, data.edge_attr

        for i, conv_layer in enumerate(self.conv_layers):
            if i != len(self.conv_layers) - 1:
                x = F.relu(conv_layer(x, edge_index, edge_weight))
            else:
                x = conv_layer(x, edge_index, edge_weight)

        return F.log_softmax(x, dim=1)

# %% [markdown]
# ### 4.3 Define the training function
# The training function is responsible for training the GCN model with the given hyperparameters and the provided dataset. The function takes the configuration and data as input and performs the training process. The function is defined as follows:

# %%
def train_gcn(config, data):
    num_neurons = int(config["num_neurons"].sample())
    network_size = int(config["network_size"].sample())
    lr = float(config["lr"].sample())
    weight_decay = float(config["weight_decay"].sample())
    # epoch_num = int(config["epoch_num"].sample())

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = GCN(data.num_node_features, int(data.y.max() + 2), num_neurons, network_size).to(device)
    data = data.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    epochs = 500
    start = 0

    # To restore a checkpoint, use `session.get_checkpoint()`.
    loaded_checkpoint = session.get_checkpoint()
    if loaded_checkpoint:
        with loaded_checkpoint.as_directory() as loaded_checkpoint_dir:
           model_state, optimizer_state = torch.load(os.path.join(loaded_checkpoint_dir, "checkpoint.pt"))
        model.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)


    checkpoint_freq = 50
    model.train()
    for epoch in range(start, epochs):
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        model.eval()
        pred = model(data).argmax(dim=1)

        train_correct = (pred[data.train_mask] == data.y[data.train_mask]).sum()
        train_acc = int(train_correct) / int(data.train_mask.sum())

        test_correct = (pred[data.test_mask] == data.y[data.test_mask]).sum()
        test_acc = int(test_correct) / int(data.test_mask.sum())

        metrics = {"accuracy": test_acc, "loss": loss.item(), "train_accuracy": train_acc}
        # if epoch % checkpoint_freq == 0:
        #     checkpoint = Checkpoint.from_dict({"epoch": epoch})
        #     session.report(metrics, checkpoint=checkpoint)
        # else:
        #     session.report(metrics)

        os.makedirs("./models/tune", exist_ok=True)
        torch.save(
            (model.state_dict(), optimizer.state_dict()), "./models/tune/checkpoint.pt")
        checkpoint = Checkpoint.from_directory("./models/tune")
        session.report(metrics, checkpoint=checkpoint)

# %%
# Load dataset
data = torch.load(dataset_path)

# Define the search space for hyperparameters
config = {
    "num_neurons": tune.choice([32, 64, 128]),
    "network_size": tune.choice([2, 3, 4]),
    "lr": tune.loguniform(1e-4, 1e-1),
    "weight_decay": tune.loguniform(1e-6, 1e-3),
    # "epoch_num": tune.choice([100, 250, 500])
}

# Define the trainable function for Ray Tune
trainable_with_resources = tune.with_resources(lambda trainable: train_gcn(config, data), {"cpu": 8, "gpu": 1})

print(data)
print("Number of Nodes:", data.num_nodes)
print("Percent Train (Split):", str(round(float(sum(data.train_mask) / len(data.train_mask)) * 10000) / 100) + "%")
# Out:
# DataBatch(edge_index=[2, 55086], rot=[3975, 3], size=[3975], x=[3975, 3], edge_attr=[55086, 1], y=[3975], train_mask=[3975], test_mask=[3975], batch=[3975], ptr=[17])
# Number of Nodes: 3975
# Percent Train (Split): 79.87%

# %% [markdown]
# ### 4.4 Perform hyperparameter tuning
# The hyperparameter tuning process using Ray Tune consists of the following steps:
#
# Define the dataset location and storage path for Ray Tune results.
# Check if the storage path exists and increment the experiment name if necessary.
# Define the search space for hyperparameters.
# Load the dataset.
# Create a trainable function with resources to train the GCN model with the provided hyperparameters and dataset.
# Initialize Ray Tune and specify the metric and mode for the ASHAScheduler.
# Define the reporter and scheduler for Ray Tune.
# Create a tuner object and specify the trainable function, search space, tune configuration, and run configuration.
# Perform the hyperparameter tuning using the tuner object.
# Retrieve the best hyperparameters and corresponding accuracy.

# %%
if __name__ == "__main__":
    ray.shutdown()
    ray.init()

    # Define the metric and mode for the ASHAScheduler
    metric = "accuracy"
    mode = "max"

    # Perform hyperparameter tuning
    # Perform hyperparameter tuning using Ray Tune
    reporter = CLIReporter(metric_columns=["accuracy"])
    scheduler = ASHAScheduler(metric=metric, mode=mode, max_t=500, grace_period=20)

    # store results using tune.Tuner
    tuner = tune.Tuner(
        trainable_with_resources,
        param_space= {
            "params": config
        },
        tune_config=TuneConfig(
            num_samples=50,
            # time_budget_s=600.0,
            scheduler=scheduler,
        ),
        run_config=RunConfig(
            name=exp_name,
            storage_path=storage_path,  # Specify a directory to store results
            progress_reporter=reporter,
        ),
    )
    result = tuner.fit()
    best_trial = result.get_best_result("accuracy", mode="max", scope="last")
    best_hyperparameters = best_trial.config
    best_accuracy = best_trial.metrics

    print("Best hyperparameters found:")
    print(best_hyperparameters)
    print("Best accuracy found:", best_accuracy)

    ray.shutdown()
# Out:
# 2023-07-10 18:26:55,633	INFO worker.py:1636 -- Started a local Ray instance.
# 2023-07-10 18:26:58,760	WARNING syncer.py:222 -- You are using remote storage, but you don't have `fsspec` installed. This can lead to inefficient syncing behavior. To avoid this, install fsspec with `pip install fsspec`. Depending on your remote storage provider, consider installing the respective fsspec-package (see https://github.com/fsspec).
# == Status ==
# Current time: 2023-07-10 18:26:59 (running for 00:00:00.64)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: None | Iter 20.000: None
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 16/50 (16 PENDING)
# +--------------------+----------+-------+-------------+-----------------------+----------------------+-----------------------+
# | Trial name         | status   | loc   |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |
# |--------------------+----------+-------+-------------+-----------------------+----------------------+-----------------------|
# | lambda_4404e_00000 | PENDING  |       | 0.0194737   |                     4 |                  128 |           3.51474e-06 |
# | lambda_4404e_00001 | PENDING  |       | 0.000259929 |                     4 |                   64 |           9.48672e-06 |
# | lambda_4404e_00002 | PENDING  |       | 0.000402415 |                     4 |                  128 |           1.61375e-05 |
# | lambda_4404e_00003 | PENDING  |       | 0.0286537   |                     4 |                   32 |           5.784e-05   |
# | lambda_4404e_00004 | PENDING  |       | 0.00169985  |                     4 |                   64 |           0.000440695 |
# | lambda_4404e_00005 | PENDING  |       | 0.00209372  |                     4 |                   32 |           0.000148741 |
# | lambda_4404e_00006 | PENDING  |       | 0.00299948  |                     4 |                  128 |           4.45076e-05 |
# | lambda_4404e_00007 | PENDING  |       | 0.00394532  |                     3 |                  128 |           4.46462e-06 |
# | lambda_4404e_00008 | PENDING  |       | 0.000109227 |                     2 |                  128 |           0.000322422 |
# | lambda_4404e_00009 | PENDING  |       | 0.0045755   |                     4 |                   32 |           2.09143e-05 |
# | lambda_4404e_00010 | PENDING  |       | 0.0372895   |                     4 |                   32 |           0.000115124 |
# | lambda_4404e_00011 | PENDING  |       | 0.0324519   |                     2 |                   64 |           3.25664e-05 |
# | lambda_4404e_00012 | PENDING  |       | 0.000462398 |                     4 |                  128 |           7.26542e-05 |
# | lambda_4404e_00013 | PENDING  |       | 0.000123237 |                     2 |                   64 |           2.79813e-05 |
# | lambda_4404e_00014 | PENDING  |       | 0.00727211  |                     2 |                   32 |           2.05195e-06 |
# | lambda_4404e_00015 | PENDING  |       | 0.0586046   |                     3 |                   32 |           7.16945e-05 |
# +--------------------+----------+-------+-------------+-----------------------+----------------------+-----------------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:04 (running for 00:00:05.65)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: None | Iter 20.000: None
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 16/50 (16 PENDING)
# +--------------------+----------+-------+-------------+-----------------------+----------------------+-----------------------+
# | Trial name         | status   | loc   |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |
# |--------------------+----------+-------+-------------+-----------------------+----------------------+-----------------------|
# | lambda_4404e_00000 | PENDING  |       | 0.0194737   |                     4 |                  128 |           3.51474e-06 |
# | lambda_4404e_00001 | PENDING  |       | 0.000259929 |                     4 |                   64 |           9.48672e-06 |
# | lambda_4404e_00002 | PENDING  |       | 0.000402415 |                     4 |                  128 |           1.61375e-05 |
# | lambda_4404e_00003 | PENDING  |       | 0.0286537   |                     4 |                   32 |           5.784e-05   |
# | lambda_4404e_00004 | PENDING  |       | 0.00169985  |                     4 |                   64 |           0.000440695 |
# | lambda_4404e_00005 | PENDING  |       | 0.00209372  |                     4 |                   32 |           0.000148741 |
# | lambda_4404e_00006 | PENDING  |       | 0.00299948  |                     4 |                  128 |           4.45076e-05 |
# | lambda_4404e_00007 | PENDING  |       | 0.00394532  |                     3 |                  128 |           4.46462e-06 |
# | lambda_4404e_00008 | PENDING  |       | 0.000109227 |                     2 |                  128 |           0.000322422 |
# | lambda_4404e_00009 | PENDING  |       | 0.0045755   |                     4 |                   32 |           2.09143e-05 |
# | lambda_4404e_00010 | PENDING  |       | 0.0372895   |                     4 |                   32 |           0.000115124 |
# | lambda_4404e_00011 | PENDING  |       | 0.0324519   |                     2 |                   64 |           3.25664e-05 |
# | lambda_4404e_00012 | PENDING  |       | 0.000462398 |                     4 |                  128 |           7.26542e-05 |
# | lambda_4404e_00013 | PENDING  |       | 0.000123237 |                     2 |                   64 |           2.79813e-05 |
# | lambda_4404e_00014 | PENDING  |       | 0.00727211  |                     2 |                   32 |           2.05195e-06 |
# | lambda_4404e_00015 | PENDING  |       | 0.0586046   |                     3 |                   32 |           7.16945e-05 |
# +--------------------+----------+-------+-------------+-----------------------+----------------------+-----------------------+
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name        </th><th style="text-align: right;">  accuracy</th><th>date               </th><th>done  </th><th>hostname  </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">    loss</th><th>node_ip  </th><th style="text-align: right;">  pid</th><th>should_checkpoint  </th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  train_accuracy</th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th></tr>
# </thead>
# <tbody>
# <tr><td>lambda_4404e_00000</td><td style="text-align: right;">   0.44875</td><td>2023-07-10_18-27-07</td><td>False </td><td>BasementPC</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.816747</td><td>127.0.0.1</td><td style="text-align: right;">12988</td><td>True               </td><td style="text-align: right;">             2.31425</td><td style="text-align: right;">           2.31425</td><td style="text-align: right;">       2.31425</td><td style="text-align: right;"> 1689031627</td><td style="text-align: right;">        0.434646</td><td style="text-align: right;">                   1</td><td>4404e_00000</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# == Status ==
# Current time: 2023-07-10 18:27:09 (running for 00:00:10.66)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: None | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |      0.605 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:14 (running for 00:00:15.66)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |    0.72125 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:19 (running for 00:00:20.69)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |     0.7875 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:24 (running for 00:00:25.76)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |     0.8125 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:29 (running for 00:00:30.79)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: None | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |      0.825 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:34 (running for 00:00:35.83)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |      0.835 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:39 (running for 00:00:40.86)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |    0.83375 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:44 (running for 00:00:45.91)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |     0.8025 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:49 (running for 00:00:50.93)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |       0.84 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:54 (running for 00:00:55.94)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 RUNNING)
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status   | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | RUNNING  | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |    0.84375 |
# | lambda_4404e_00001 | PENDING  |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING  |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING  |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING  |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING  |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING  |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING  |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING  |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING  |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING  |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING  |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING  |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING  |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING  |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING  |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING  |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# +--------------------+----------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:27:59 (running for 00:01:00.97)
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 17/50 (16 PENDING, 1 TERMINATED)
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status     | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00001 | PENDING    |                 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |            |
# | lambda_4404e_00002 | PENDING    |                 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |            |
# | lambda_4404e_00003 | PENDING    |                 | 0.0286537   |                     4 |                   32 |           5.784e-05   |            |
# | lambda_4404e_00004 | PENDING    |                 | 0.00169985  |                     4 |                   64 |           0.000440695 |            |
# | lambda_4404e_00005 | PENDING    |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING    |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING    |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING    |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# | lambda_4404e_00009 | PENDING    |                 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |            |
# | lambda_4404e_00010 | PENDING    |                 | 0.0372895   |                     4 |                   32 |           0.000115124 |            |
# | lambda_4404e_00011 | PENDING    |                 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |            |
# | lambda_4404e_00012 | PENDING    |                 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |            |
# | lambda_4404e_00013 | PENDING    |                 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |            |
# | lambda_4404e_00014 | PENDING    |                 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |            |
# | lambda_4404e_00015 | PENDING    |                 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |            |
# | lambda_4404e_00016 | PENDING    |                 | 0.00109593  |                     2 |                   32 |           0.000275333 |            |
# | lambda_4404e_00000 | TERMINATED | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |      0.845 |
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# == Status ==
# Current time: 2023-07-10 18:28:04 (running for 00:01:06.02)
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 320.000: 0.835 | Iter 80.000: 0.66625 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 21/50 (16 PENDING, 1 RUNNING, 4 TERMINATED)
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status     | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00004 | RUNNING    | 127.0.0.1:12988 | 0.00169985  |                     4 |                   64 |           0.000440695 |    0.45    |
# | lambda_4404e_00005 | PENDING    |                 | 0.00209372  |                     4 |                   32 |           0.000148741 |            |
# | lambda_4404e_00006 | PENDING    |                 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |            |
# | lambda_4404e_00007 | PENDING    |                 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |            |
# | lambda_4404e_00008 | PENDING    |                 | 0.000109227 |                     2 |                  128 |           0.000322422 |            |
# ...
# | lambda_4404e_00002 | TERMINATED | 127.0.0.1:12988 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |    0.44875 |
# | lambda_4404e_00003 | TERMINATED | 127.0.0.1:12988 | 0.0286537   |                     4 |                   32 |           5.784e-05   |    0.5275  |
# | lambda_4404e_00004 | TERMINATED | 127.0.0.1:12988 | 0.00169985  |                     4 |                   64 |           0.000440695 |    0.585   |
# | lambda_4404e_00005 | TERMINATED | 127.0.0.1:12988 | 0.00209372  |                     4 |                   32 |           0.000148741 |    0.6075  |
# | lambda_4404e_00006 | TERMINATED | 127.0.0.1:12988 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |    0.4525  |
# | lambda_4404e_00007 | TERMINATED | 127.0.0.1:12988 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |    0.55125 |
# | lambda_4404e_00008 | TERMINATED | 127.0.0.1:12988 | 0.000109227 |                     2 |                  128 |           0.000322422 |    0.485   |
# | lambda_4404e_00009 | TERMINATED | 127.0.0.1:12988 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |    0.5975  |
# | lambda_4404e_00010 | TERMINATED | 127.0.0.1:12988 | 0.0372895   |                     4 |                   32 |           0.000115124 |    0.56625 |
# | lambda_4404e_00011 | TERMINATED | 127.0.0.1:12988 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |    0.4825  |
# | lambda_4404e_00012 | TERMINATED | 127.0.0.1:12988 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |    0.38125 |
# | lambda_4404e_00013 | TERMINATED | 127.0.0.1:12988 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |    0.41875 |
# | lambda_4404e_00014 | TERMINATED | 127.0.0.1:12988 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |    0.6     |
# | lambda_4404e_00015 | TERMINATED | 127.0.0.1:12988 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |    0.56625 |
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# ... 30 more trials not shown (30 TERMINATED)
#
#
# == Status ==
# Current time: 2023-07-10 18:33:47 (running for 00:06:48.39)
# Using AsyncHyperBand: num_stopped=49
# Bracket: Iter 320.000: 0.81125 | Iter 80.000: 0.6175 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status     | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00049 | RUNNING    | 127.0.0.1:12988 | 0.000193133 |                     2 |                   64 |           0.000870385 |    0.55125 |
# | lambda_4404e_00000 | TERMINATED | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |    0.845   |
# | lambda_4404e_00001 | TERMINATED | 127.0.0.1:12988 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |    0.50875 |
# | lambda_4404e_00002 | TERMINATED | 127.0.0.1:12988 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |    0.44875 |
# | lambda_4404e_00003 | TERMINATED | 127.0.0.1:12988 | 0.0286537   |                     4 |                   32 |           5.784e-05   |    0.5275  |
# | lambda_4404e_00004 | TERMINATED | 127.0.0.1:12988 | 0.00169985  |                     4 |                   64 |           0.000440695 |    0.585   |
# | lambda_4404e_00005 | TERMINATED | 127.0.0.1:12988 | 0.00209372  |                     4 |                   32 |           0.000148741 |    0.6075  |
# | lambda_4404e_00006 | TERMINATED | 127.0.0.1:12988 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |    0.4525  |
# | lambda_4404e_00007 | TERMINATED | 127.0.0.1:12988 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |    0.55125 |
# | lambda_4404e_00008 | TERMINATED | 127.0.0.1:12988 | 0.000109227 |                     2 |                  128 |           0.000322422 |    0.485   |
# | lambda_4404e_00009 | TERMINATED | 127.0.0.1:12988 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |    0.5975  |
# | lambda_4404e_00010 | TERMINATED | 127.0.0.1:12988 | 0.0372895   |                     4 |                   32 |           0.000115124 |    0.56625 |
# | lambda_4404e_00011 | TERMINATED | 127.0.0.1:12988 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |    0.4825  |
# | lambda_4404e_00012 | TERMINATED | 127.0.0.1:12988 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |    0.38125 |
# | lambda_4404e_00013 | TERMINATED | 127.0.0.1:12988 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |    0.41875 |
# | lambda_4404e_00014 | TERMINATED | 127.0.0.1:12988 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |    0.6     |
# | lambda_4404e_00015 | TERMINATED | 127.0.0.1:12988 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |    0.56625 |
# | lambda_4404e_00016 | TERMINATED | 127.0.0.1:12988 | 0.00109593  |                     2 |                   32 |           0.000275333 |    0.49    |
# | lambda_4404e_00017 | TERMINATED | 127.0.0.1:12988 | 0.000633557 |                     4 |                   64 |           2.83487e-06 |    0.45    |
# | lambda_4404e_00018 | TERMINATED | 127.0.0.1:12988 | 0.000397092 |                     4 |                  128 |           5.8268e-05  |    0.7275  |
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# ... 30 more trials not shown (30 TERMINATED)
# 2023-07-10 18:33:52,584	INFO tune.py:1111 -- Total run time: 413.82 seconds (412.72 seconds for the tuning loop).
# == Status ==
# Current time: 2023-07-10 18:33:52 (running for 00:06:53.75)
# Using AsyncHyperBand: num_stopped=50
# Bracket: Iter 320.000: 0.81125 | Iter 80.000: 0.6171875 | Iter 20.000: 0.55125
# Logical resource usage: 8.0/8 CPUs, 1.0/1 GPUs
# Result logdir: C:\Users\Shamit\ray_results\tune_analyzing_results_2
# Number of trials: 50/50 (50 TERMINATED)
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
# | Trial name         | status     | loc             |   params/lr |   params/network_size |   params/num_neurons |   params/weight_decay |   accuracy |
# |--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------|
# | lambda_4404e_00000 | TERMINATED | 127.0.0.1:12988 | 0.0194737   |                     4 |                  128 |           3.51474e-06 |    0.845   |
# | lambda_4404e_00001 | TERMINATED | 127.0.0.1:12988 | 0.000259929 |                     4 |                   64 |           9.48672e-06 |    0.50875 |
# | lambda_4404e_00002 | TERMINATED | 127.0.0.1:12988 | 0.000402415 |                     4 |                  128 |           1.61375e-05 |    0.44875 |
# | lambda_4404e_00003 | TERMINATED | 127.0.0.1:12988 | 0.0286537   |                     4 |                   32 |           5.784e-05   |    0.5275  |
# | lambda_4404e_00004 | TERMINATED | 127.0.0.1:12988 | 0.00169985  |                     4 |                   64 |           0.000440695 |    0.585   |
# | lambda_4404e_00005 | TERMINATED | 127.0.0.1:12988 | 0.00209372  |                     4 |                   32 |           0.000148741 |    0.6075  |
# | lambda_4404e_00006 | TERMINATED | 127.0.0.1:12988 | 0.00299948  |                     4 |                  128 |           4.45076e-05 |    0.4525  |
# | lambda_4404e_00007 | TERMINATED | 127.0.0.1:12988 | 0.00394532  |                     3 |                  128 |           4.46462e-06 |    0.55125 |
# | lambda_4404e_00008 | TERMINATED | 127.0.0.1:12988 | 0.000109227 |                     2 |                  128 |           0.000322422 |    0.485   |
# | lambda_4404e_00009 | TERMINATED | 127.0.0.1:12988 | 0.0045755   |                     4 |                   32 |           2.09143e-05 |    0.5975  |
# | lambda_4404e_00010 | TERMINATED | 127.0.0.1:12988 | 0.0372895   |                     4 |                   32 |           0.000115124 |    0.56625 |
# | lambda_4404e_00011 | TERMINATED | 127.0.0.1:12988 | 0.0324519   |                     2 |                   64 |           3.25664e-05 |    0.4825  |
# | lambda_4404e_00012 | TERMINATED | 127.0.0.1:12988 | 0.000462398 |                     4 |                  128 |           7.26542e-05 |    0.38125 |
# | lambda_4404e_00013 | TERMINATED | 127.0.0.1:12988 | 0.000123237 |                     2 |                   64 |           2.79813e-05 |    0.41875 |
# | lambda_4404e_00014 | TERMINATED | 127.0.0.1:12988 | 0.00727211  |                     2 |                   32 |           2.05195e-06 |    0.6     |
# | lambda_4404e_00015 | TERMINATED | 127.0.0.1:12988 | 0.0586046   |                     3 |                   32 |           7.16945e-05 |    0.56625 |
# | lambda_4404e_00016 | TERMINATED | 127.0.0.1:12988 | 0.00109593  |                     2 |                   32 |           0.000275333 |    0.49    |
# | lambda_4404e_00017 | TERMINATED | 127.0.0.1:12988 | 0.000633557 |                     4 |                   64 |           2.83487e-06 |    0.45    |
# | lambda_4404e_00018 | TERMINATED | 127.0.0.1:12988 | 0.000397092 |                     4 |                  128 |           5.8268e-05  |    0.7275  |
# | lambda_4404e_00019 | TERMINATED | 127.0.0.1:12988 | 0.0160509   |                     4 |                   32 |           0.000144082 |    0.79125 |
# | lambda_4404e_00020 | TERMINATED | 127.0.0.1:12988 | 0.0366459   |                     3 |                   64 |           5.82334e-06 |    0.6125  |
# | lambda_4404e_00021 | TERMINATED | 127.0.0.1:12988 | 0.000348431 |                     4 |                   64 |           1.86895e-05 |    0.60375 |
# | lambda_4404e_00022 | TERMINATED | 127.0.0.1:12988 | 0.000908875 |                     2 |                   32 |           8.22772e-06 |    0.55125 |
# | lambda_4404e_00023 | TERMINATED | 127.0.0.1:12988 | 0.000772503 |                     4 |                   32 |           1.31919e-06 |    0.56625 |
# | lambda_4404e_00024 | TERMINATED | 127.0.0.1:12988 | 0.0309211   |                     4 |                  128 |           0.000362597 |    0.44875 |
# | lambda_4404e_00025 | TERMINATED | 127.0.0.1:12988 | 0.00216509  |                     4 |                   32 |           1.74825e-05 |    0.55375 |
# | lambda_4404e_00026 | TERMINATED | 127.0.0.1:12988 | 0.010338    |                     3 |                  128 |           0.000168707 |    0.42375 |
# | lambda_4404e_00027 | TERMINATED | 127.0.0.1:12988 | 0.0144723   |                     2 |                   64 |           0.000202207 |    0.77625 |
# | lambda_4404e_00028 | TERMINATED | 127.0.0.1:12988 | 0.000370757 |                     2 |                  128 |           3.73255e-06 |    0.55    |
# | lambda_4404e_00029 | TERMINATED | 127.0.0.1:12988 | 0.00114018  |                     3 |                   64 |           0.000181697 |    0.5725  |
# | lambda_4404e_00030 | TERMINATED | 127.0.0.1:12988 | 0.00272913  |                     2 |                   32 |           2.94533e-05 |    0.5325  |
# | lambda_4404e_00031 | TERMINATED | 127.0.0.1:12988 | 0.0125326   |                     3 |                  128 |           4.09918e-06 |    0.58375 |
# | lambda_4404e_00032 | TERMINATED | 127.0.0.1:12988 | 0.0015537   |                     4 |                   64 |           9.79618e-06 |    0.60375 |
# | lambda_4404e_00033 | TERMINATED | 127.0.0.1:12988 | 0.0125846   |                     3 |                   64 |           4.91329e-05 |    0.82    |
# | lambda_4404e_00034 | TERMINATED | 127.0.0.1:12988 | 0.0180001   |                     3 |                  128 |           7.31214e-06 |    0.81    |
# | lambda_4404e_00035 | TERMINATED | 127.0.0.1:12988 | 0.0124683   |                     2 |                   32 |           2.59151e-05 |    0.45625 |
# | lambda_4404e_00036 | TERMINATED | 127.0.0.1:12988 | 0.0051609   |                     4 |                   32 |           1.53523e-05 |    0.61625 |
# | lambda_4404e_00037 | TERMINATED | 127.0.0.1:12988 | 0.0276348   |                     2 |                   64 |           1.00208e-05 |    0.55125 |
# | lambda_4404e_00038 | TERMINATED | 127.0.0.1:12988 | 0.0244263   |                     4 |                  128 |           4.84326e-05 |    0.55125 |
# | lambda_4404e_00039 | TERMINATED | 127.0.0.1:12988 | 0.0182622   |                     2 |                   32 |           1.35748e-06 |    0.5425  |
# | lambda_4404e_00040 | TERMINATED | 127.0.0.1:12988 | 0.00258534  |                     2 |                   64 |           0.000768895 |    0.37125 |
# | lambda_4404e_00041 | TERMINATED | 127.0.0.1:12988 | 0.00270154  |                     4 |                  128 |           1.2319e-06  |    0.795   |
# | lambda_4404e_00042 | TERMINATED | 127.0.0.1:12988 | 0.000721809 |                     2 |                   32 |           1.45032e-05 |    0.4475  |
# | lambda_4404e_00043 | TERMINATED | 127.0.0.1:12988 | 0.0132611   |                     3 |                   64 |           3.31401e-05 |    0.48875 |
# | lambda_4404e_00044 | TERMINATED | 127.0.0.1:12988 | 0.0296186   |                     2 |                  128 |           0.00016031  |    0.6     |
# | lambda_4404e_00045 | TERMINATED | 127.0.0.1:12988 | 0.00016917  |                     4 |                   32 |           5.94126e-05 |    0.58625 |
# | lambda_4404e_00046 | TERMINATED | 127.0.0.1:12988 | 0.00241422  |                     4 |                  128 |           5.95689e-06 |    0.6075  |
# | lambda_4404e_00047 | TERMINATED | 127.0.0.1:12988 | 0.0095637   |                     3 |                   32 |           1.07929e-06 |    0.495   |
# | lambda_4404e_00048 | TERMINATED | 127.0.0.1:12988 | 0.00266942  |                     2 |                  128 |           0.000794523 |    0.48375 |
# | lambda_4404e_00049 | TERMINATED | 127.0.0.1:12988 | 0.000193133 |                     2 |                   64 |           0.000870385 |    0.61    |
# +--------------------+------------+-----------------+-------------+-----------------------+----------------------+-----------------------+------------+
#
#
# Best hyperparameters found:
# {'params': {'num_neurons': 128, 'network_size': 4, 'lr': 0.019473744418527204, 'weight_decay': 3.514742147317445e-06}}
# Best accuracy found: {'accuracy': 0.845, 'loss': 0.40148797631263733, 'train_accuracy': 0.8324409448818898, 'time_this_iter_s': 0.1218266487121582, 'should_checkpoint': True, 'done': True, 'training_iteration': 500, 'trial_id': '4404e_00000', 'date': '2023-07-10_18-27-59', 'timestamp': 1689031679, 'time_total_s': 54.73682403564453, 'pid': 12988, 'hostname': 'BasementPC', 'node_ip': '127.0.0.1', 'config': {'params': {'num_neurons': 128, 'network_size': 4, 'lr': 0.019473744418527204, 'weight_decay': 3.514742147317445e-06}}, 'time_since_restore': 54.73682403564453, 'iterations_since_restore': 500, 'experiment_tag': '0_lr=0.0195,network_size=4,num_neurons=128,weight_decay=0.0000'}

# %%
# restored_tuner = tune.Tuner.restore(experiment_path, trainable=trainable_with_resources)
# restored_tuner.get_results()

tuner.get_results()
# Out:
# ResultGrid<[
#   Result(
#     metrics={'accuracy': 0.845, 'loss': 0.40148797631263733, 'train_accuracy': 0.8324409448818898, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00000', 'experiment_tag': '0_lr=0.0195,network_size=4,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00000_0_lr=0.0195,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00000_0_lr=0.0195,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000499)
#   ),
#   Result(
#     metrics={'accuracy': 0.50875, 'loss': 1.1151809692382812, 'train_accuracy': 0.5250393700787401, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00001', 'experiment_tag': '1_lr=0.0003,network_size=4,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00001_1_lr=0.0003,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00001_1_lr=0.0003,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.44875, 'loss': 6.944567680358887, 'train_accuracy': 0.43811023622047246, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00002', 'experiment_tag': '2_lr=0.0004,network_size=4,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00002_2_lr=0.0004,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00002_2_lr=0.0004,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.5275, 'loss': 3.4098424911499023, 'train_accuracy': 0.5244094488188976, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00003', 'experiment_tag': '3_lr=0.0287,network_size=4,num_neurons=32,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00003_3_lr=0.0287,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00003_3_lr=0.0287,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.585, 'loss': 0.6618557572364807, 'train_accuracy': 0.5968503937007874, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00004', 'experiment_tag': '4_lr=0.0017,network_size=4,num_neurons=64,weight_decay=0.0004'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00004_4_lr=0.0017,network_size=4,num_neurons=64,weight_decay=0.0004_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00004_4_lr=0.0017,network_size=4,num_neurons=64,weight_decay=0.0004_2023-07-10_18-26-59\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.6075, 'loss': 0.6547302603721619, 'train_accuracy': 0.5937007874015748, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00005', 'experiment_tag': '5_lr=0.0021,network_size=4,num_neurons=32,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00005_5_lr=0.0021,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00005_5_lr=0.0021,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.4525, 'loss': 0.7355286478996277, 'train_accuracy': 0.43811023622047246, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00006', 'experiment_tag': '6_lr=0.0030,network_size=4,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00006_6_lr=0.0030,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00006_6_lr=0.0030,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.55125, 'loss': 0.69748854637146, 'train_accuracy': 0.5618897637795276, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00007', 'experiment_tag': '7_lr=0.0039,network_size=3,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00007_7_lr=0.0039,network_size=3,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00007_7_lr=0.0039,network_size=3,num_neurons=128,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.485, 'loss': 0.714167058467865, 'train_accuracy': 0.44535433070866143, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00008', 'experiment_tag': '8_lr=0.0001,network_size=2,num_neurons=128,weight_decay=0.0003'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00008_8_lr=0.0001,network_size=2,num_neurons=128,weight_decay=0.0003_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00008_8_lr=0.0001,network_size=2,num_neurons=128,weight_decay=0.0003_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.5975, 'loss': 0.656454861164093, 'train_accuracy': 0.6053543307086614, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00009', 'experiment_tag': '9_lr=0.0046,network_size=4,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00009_9_lr=0.0046,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00009_9_lr=0.0046,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.56625, 'loss': 0.6803706884384155, 'train_accuracy': 0.573228346456693, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00010', 'experiment_tag': '10_lr=0.0373,network_size=4,num_neurons=32,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00010_10_lr=0.0373,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00010_10_lr=0.0373,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.4825, 'loss': 0.707480251789093, 'train_accuracy': 0.4818897637795276, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00011', 'experiment_tag': '11_lr=0.0325,network_size=2,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00011_11_lr=0.0325,network_size=2,num_neurons=64,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00011_11_lr=0.0325,network_size=2,num_neurons=64,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.38125, 'loss': 3.4974043369293213, 'train_accuracy': 0.36283464566929136, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00012', 'experiment_tag': '12_lr=0.0005,network_size=4,num_neurons=128,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00012_12_lr=0.0005,network_size=4,num_neurons=128,weight_decay=0.0001_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00012_12_lr=0.0005,network_size=4,num_neurons=128,weight_decay=0.0001_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.41875, 'loss': 0.6889798641204834, 'train_accuracy': 0.40283464566929134, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00013', 'experiment_tag': '13_lr=0.0001,network_size=2,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00013_13_lr=0.0001,network_size=2,num_neurons=64,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00013_13_lr=0.0001,network_size=2,num_neurons=64,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.6, 'loss': 0.6468631625175476, 'train_accuracy': 0.6075590551181103, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00014', 'experiment_tag': '14_lr=0.0073,network_size=2,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00014_14_lr=0.0073,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00014_14_lr=0.0073,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-26-59\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.56625, 'loss': 0.6639269590377808, 'train_accuracy': 0.5725984251968504, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00015', 'experiment_tag': '15_lr=0.0586,network_size=3,num_neurons=32,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00015_15_lr=0.0586,network_size=3,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00015_15_lr=0.0586,network_size=3,num_neurons=32,weight_decay=0.0001_2023-07-10_18-26-59\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.49, 'loss': 0.6729819774627686, 'train_accuracy': 0.49984251968503934, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00016', 'experiment_tag': '16_lr=0.0011,network_size=2,num_neurons=32,weight_decay=0.0003'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00016_16_lr=0.0011,network_size=2,num_neurons=32,weight_decay=0.0003_2023-07-10_18-27-04',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00016_16_lr=0.0011,network_size=2,num_neurons=32,weight_decay=0.0003_2023-07-10_18-27-04\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.45, 'loss': 1.2114667892456055, 'train_accuracy': 0.45574803149606297, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00017', 'experiment_tag': '17_lr=0.0006,network_size=4,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00017_17_lr=0.0006,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-27-59',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00017_17_lr=0.0006,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-27-59\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.7275, 'loss': 0.5822386145591736, 'train_accuracy': 0.7196850393700788, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00018', 'experiment_tag': '18_lr=0.0004,network_size=4,num_neurons=128,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00018_18_lr=0.0004,network_size=4,num_neurons=128,weight_decay=0.0001_2023-07-10_18-28-01',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00018_18_lr=0.0004,network_size=4,num_neurons=128,weight_decay=0.0001_2023-07-10_18-28-01\checkpoint_000319)
#   ),
#   Result(
#     metrics={'accuracy': 0.79125, 'loss': 0.4600232243537903, 'train_accuracy': 0.7899212598425197, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00019', 'experiment_tag': '19_lr=0.0161,network_size=4,num_neurons=32,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00019_19_lr=0.0161,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-28-02',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00019_19_lr=0.0161,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-28-02\checkpoint_000319)
#   ),
#   Result(
#     metrics={'accuracy': 0.6125, 'loss': 0.6498106718063354, 'train_accuracy': 0.6163779527559056, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00020', 'experiment_tag': '20_lr=0.0366,network_size=3,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00020_20_lr=0.0366,network_size=3,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-03',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00020_20_lr=0.0366,network_size=3,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-03\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.60375, 'loss': 0.6560487151145935, 'train_accuracy': 0.6185826771653543, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00021', 'experiment_tag': '21_lr=0.0003,network_size=4,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00021_21_lr=0.0003,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-08',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00021_21_lr=0.0003,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-08\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.55125, 'loss': 0.6725084781646729, 'train_accuracy': 0.5622047244094488, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00022', 'experiment_tag': '22_lr=0.0009,network_size=2,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00022_22_lr=0.0009,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-13',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00022_22_lr=0.0009,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-13\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.56625, 'loss': 0.672933042049408, 'train_accuracy': 0.5795275590551181, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00023', 'experiment_tag': '23_lr=0.0008,network_size=4,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00023_23_lr=0.0008,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-14',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00023_23_lr=0.0008,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-14\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.44875, 'loss': 0.7832298874855042, 'train_accuracy': 0.43811023622047246, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00024', 'experiment_tag': '24_lr=0.0309,network_size=4,num_neurons=128,weight_decay=0.0004'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00024_24_lr=0.0309,network_size=4,num_neurons=128,weight_decay=0.0004_2023-07-10_18-28-16',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00024_24_lr=0.0309,network_size=4,num_neurons=128,weight_decay=0.0004_2023-07-10_18-28-16\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.55375, 'loss': 0.6825964450836182, 'train_accuracy': 0.5644094488188977, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00025', 'experiment_tag': '25_lr=0.0022,network_size=4,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00025_25_lr=0.0022,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-17',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00025_25_lr=0.0022,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-17\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.42375, 'loss': 0.7872015833854675, 'train_accuracy': 0.4371653543307087, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00026', 'experiment_tag': '26_lr=0.0103,network_size=3,num_neurons=128,weight_decay=0.0002'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00026_26_lr=0.0103,network_size=3,num_neurons=128,weight_decay=0.0002_2023-07-10_18-28-23',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00026_26_lr=0.0103,network_size=3,num_neurons=128,weight_decay=0.0002_2023-07-10_18-28-23\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.77625, 'loss': 0.48200294375419617, 'train_accuracy': 0.7735433070866141, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00027', 'experiment_tag': '27_lr=0.0145,network_size=2,num_neurons=64,weight_decay=0.0002'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00027_27_lr=0.0145,network_size=2,num_neurons=64,weight_decay=0.0002_2023-07-10_18-28-28',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00027_27_lr=0.0145,network_size=2,num_neurons=64,weight_decay=0.0002_2023-07-10_18-28-28\checkpoint_000319)
#   ),
#   Result(
#     metrics={'accuracy': 0.55, 'loss': 0.6838372945785522, 'train_accuracy': 0.5618897637795276, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00028', 'experiment_tag': '28_lr=0.0004,network_size=2,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00028_28_lr=0.0004,network_size=2,num_neurons=128,weight_decay=0.0000_2023-07-10_18-28-29',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00028_28_lr=0.0004,network_size=2,num_neurons=128,weight_decay=0.0000_2023-07-10_18-28-29\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.5725, 'loss': 0.6713364124298096, 'train_accuracy': 0.5814173228346456, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00029', 'experiment_tag': '29_lr=0.0011,network_size=3,num_neurons=64,weight_decay=0.0002'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00029_29_lr=0.0011,network_size=3,num_neurons=64,weight_decay=0.0002_2023-07-10_18-28-30',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00029_29_lr=0.0011,network_size=3,num_neurons=64,weight_decay=0.0002_2023-07-10_18-28-30\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.5325, 'loss': 0.7236585021018982, 'train_accuracy': 0.5584251968503937, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00030', 'experiment_tag': '30_lr=0.0027,network_size=2,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00030_30_lr=0.0027,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-31',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00030_30_lr=0.0027,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-28-31\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.58375, 'loss': 0.6705032587051392, 'train_accuracy': 0.590236220472441, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00031', 'experiment_tag': '31_lr=0.0125,network_size=3,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00031_31_lr=0.0125,network_size=3,num_neurons=128,weight_decay=0.0000_2023-07-10_18-28-37',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00031_31_lr=0.0125,network_size=3,num_neurons=128,weight_decay=0.0000_2023-07-10_18-28-37\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.60375, 'loss': 0.6444969177246094, 'train_accuracy': 0.6066141732283464, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00032', 'experiment_tag': '32_lr=0.0016,network_size=4,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00032_32_lr=0.0016,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-42',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00032_32_lr=0.0016,network_size=4,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-42\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.82, 'loss': 0.424821674823761, 'train_accuracy': 0.8233070866141732, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00033', 'experiment_tag': '33_lr=0.0126,network_size=3,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00033_33_lr=0.0126,network_size=3,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-43',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00033_33_lr=0.0126,network_size=3,num_neurons=64,weight_decay=0.0000_2023-07-10_18-28-43\checkpoint_000499)
#   ),
#   Result(
#     metrics={'accuracy': 0.81, 'loss': 0.44569459557533264, 'train_accuracy': 0.8025196850393701, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00034', 'experiment_tag': '34_lr=0.0180,network_size=3,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00034_34_lr=0.0180,network_size=3,num_neurons=128,weight_decay=0.0000_2023-07-10_18-28-44',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00034_34_lr=0.0180,network_size=3,num_neurons=128,weight_decay=0.0000_2023-07-10_18-28-44\checkpoint_000319)
#   ),
#   Result(
#     metrics={'accuracy': 0.45625, 'loss': 0.7425658106803894, 'train_accuracy': 0.4532283464566929, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00035', 'experiment_tag': '35_lr=0.0125,network_size=2,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00035_35_lr=0.0125,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-29-13',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00035_35_lr=0.0125,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-29-13\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.61625, 'loss': 0.6291137337684631, 'train_accuracy': 0.6299212598425197, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00036', 'experiment_tag': '36_lr=0.0052,network_size=4,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00036_36_lr=0.0052,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-29-45',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00036_36_lr=0.0052,network_size=4,num_neurons=32,weight_decay=0.0000_2023-07-10_18-29-45\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.55125, 'loss': 3.9995028972625732, 'train_accuracy': 0.5618897637795276, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00037', 'experiment_tag': '37_lr=0.0276,network_size=2,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00037_37_lr=0.0276,network_size=2,num_neurons=64,weight_decay=0.0000_2023-07-10_18-29-50',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00037_37_lr=0.0276,network_size=2,num_neurons=64,weight_decay=0.0000_2023-07-10_18-29-50\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.55125, 'loss': 0.7654731869697571, 'train_accuracy': 0.5618897637795276, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00038', 'experiment_tag': '38_lr=0.0244,network_size=4,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00038_38_lr=0.0244,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-29-56',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00038_38_lr=0.0244,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-29-56\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.5425, 'loss': 0.9765729308128357, 'train_accuracy': 0.567244094488189, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00039', 'experiment_tag': '39_lr=0.0183,network_size=2,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00039_39_lr=0.0183,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-30-01',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00039_39_lr=0.0183,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-30-01\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.37125, 'loss': 1.2722554206848145, 'train_accuracy': 0.37984251968503935, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00040', 'experiment_tag': '40_lr=0.0026,network_size=2,num_neurons=64,weight_decay=0.0008'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00040_40_lr=0.0026,network_size=2,num_neurons=64,weight_decay=0.0008_2023-07-10_18-30-06',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00040_40_lr=0.0026,network_size=2,num_neurons=64,weight_decay=0.0008_2023-07-10_18-30-06\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.795, 'loss': 0.4580250680446625, 'train_accuracy': 0.7811023622047244, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00041', 'experiment_tag': '41_lr=0.0027,network_size=4,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00041_41_lr=0.0027,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-30-08',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00041_41_lr=0.0027,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-30-08\checkpoint_000319)
#   ),
#   Result(
#     metrics={'accuracy': 0.4475, 'loss': 0.8325034379959106, 'train_accuracy': 0.4368503937007874, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00042', 'experiment_tag': '42_lr=0.0007,network_size=2,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00042_42_lr=0.0007,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-30-13',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00042_42_lr=0.0007,network_size=2,num_neurons=32,weight_decay=0.0000_2023-07-10_18-30-13\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.48875, 'loss': 0.7010439038276672, 'train_accuracy': 0.4837795275590551, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00043', 'experiment_tag': '43_lr=0.0133,network_size=3,num_neurons=64,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00043_43_lr=0.0133,network_size=3,num_neurons=64,weight_decay=0.0000_2023-07-10_18-30-15',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00043_43_lr=0.0133,network_size=3,num_neurons=64,weight_decay=0.0000_2023-07-10_18-30-15\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.6, 'loss': 0.6509792804718018, 'train_accuracy': 0.5962204724409449, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00044', 'experiment_tag': '44_lr=0.0296,network_size=2,num_neurons=128,weight_decay=0.0002'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00044_44_lr=0.0296,network_size=2,num_neurons=128,weight_decay=0.0002_2023-07-10_18-30-49',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00044_44_lr=0.0296,network_size=2,num_neurons=128,weight_decay=0.0002_2023-07-10_18-30-49\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.58625, 'loss': 0.6534279584884644, 'train_accuracy': 0.5930708661417323, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00045', 'experiment_tag': '45_lr=0.0002,network_size=4,num_neurons=32,weight_decay=0.0001'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00045_45_lr=0.0002,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-30-51',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00045_45_lr=0.0002,network_size=4,num_neurons=32,weight_decay=0.0001_2023-07-10_18-30-51\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.6075, 'loss': 0.6512221693992615, 'train_accuracy': 0.60251968503937, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00046', 'experiment_tag': '46_lr=0.0024,network_size=4,num_neurons=128,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00046_46_lr=0.0024,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-30-56',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00046_46_lr=0.0024,network_size=4,num_neurons=128,weight_decay=0.0000_2023-07-10_18-30-56\checkpoint_000079)
#   ),
#   Result(
#     metrics={'accuracy': 0.495, 'loss': 0.6932705640792847, 'train_accuracy': 0.4966929133858268, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00047', 'experiment_tag': '47_lr=0.0096,network_size=3,num_neurons=32,weight_decay=0.0000'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00047_47_lr=0.0096,network_size=3,num_neurons=32,weight_decay=0.0000_2023-07-10_18-30-57',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00047_47_lr=0.0096,network_size=3,num_neurons=32,weight_decay=0.0000_2023-07-10_18-30-57\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.48375, 'loss': 0.6942980885505676, 'train_accuracy': 0.46488188976377953, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00048', 'experiment_tag': '48_lr=0.0027,network_size=2,num_neurons=128,weight_decay=0.0008'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00048_48_lr=0.0027,network_size=2,num_neurons=128,weight_decay=0.0008_2023-07-10_18-31-05',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00048_48_lr=0.0027,network_size=2,num_neurons=128,weight_decay=0.0008_2023-07-10_18-31-05\checkpoint_000019)
#   ),
#   Result(
#     metrics={'accuracy': 0.61, 'loss': 0.6618562340736389, 'train_accuracy': 0.608503937007874, 'should_checkpoint': True, 'done': True, 'trial_id': '4404e_00049', 'experiment_tag': '49_lr=0.0002,network_size=2,num_neurons=64,weight_decay=0.0009'},
#     path='e://\\OneDrive\\UWM\\William_Musinski__Surana\\Research_Code\\Research\\notebooks\\ray_results\\tune_analyzing_results_2\\lambda_4404e_00049_49_lr=0.0002,network_size=2,num_neurons=64,weight_decay=0.0009_2023-07-10_18-31-10',
#     checkpoint=Checkpoint(uri=e://\OneDrive\UWM\William_Musinski__Surana\Research_Code\Research\notebooks\ray_results\tune_analyzing_results_2\lambda_4404e_00049_49_lr=0.0002,network_size=2,num_neurons=64,weight_decay=0.0009_2023-07-10_18-31-10\checkpoint_000079)
#   )
# ]>

# %% [markdown]
# ### 4.5 Visualize the results
# The results of the hyperparameter tuning process are stored in the specified storage path. The results can be loaded and visualized using TensorBoard. The code snippet below demonstrates the loading and visualization of the results

# %%
print(f"Loading results from {experiment_path}...")
# %reload_ext tensorboard

# %tensorboard --logdir $experiment_path
# Out:
# Loading results from ./ray_results/tune_analyzing_results_2...
# Launching TensorBoard...
#       <iframe id="tensorboard-frame-6175cffb1ff2ba10" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6175cffb1ff2ba10");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### 4.6 Analyze the results
# In tensorboard, you can see the accuracy increase and loss decrease over time. The test accuracy (just labeled `accuracy` in tensorboard), should correlate to the training accuracy (labeled `train_accuracy`). If not, the model may be overfitting.
#
# To view specific hyperparameters, click on the hyperparameter tab. The hyperparameter tab shows the distribution of the hyperparameters and the corresponding accuracy. The hyperparameter tab also shows the best hyperparameters and the corresponding accuracy.
